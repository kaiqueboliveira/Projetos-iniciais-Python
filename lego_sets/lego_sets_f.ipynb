# %%
#importar a biblioteca pandas
import pandas as pd


#ler o arquivo em csv
df = pd.read_csv('/Users/kaique/Documents/vscode_python/lego_sets/lego_sets.csv')

themes = pd.read_csv('lego_sets/themes.csv')

parent_themes = pd.read_csv('lego_sets/parent_themes.csv')

sets = pd.read_csv('lego_sets/sets.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 8
#       5 #ler o arquivo em csv
#       6 df = pd.read_csv('/Users/kaique/Documents/vscode_python/lego_sets/lego_sets.csv')
# ----> 8 themes = pd.read_csv('lego_sets/themes.csv')
#      10 parent_themes = pd.read_csv('lego_sets/parent_themes.csv')
#      12 sets = pd.read_csv('lego_sets/sets.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lego_sets/themes.csv'

# %%
sets.head()
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0    00-1             Weetabix Castle  1970       414        471
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %%
themes.head()
# Out:
#    id            name  parent_id
# 0   1         Technic        NaN
# 1   2  Arctic Technic        1.0
# 2   3     Competition        1.0
# 3   4  Expert Builder        1.0
# 4   5           Model        1.0

# %%
#retorna apenas os temas licenciado
temas_licenciado = parent_themes[parent_themes['is_licensed'] == True]
temas_licenciado.head()
# Out:
#      id                      name  is_licensed
# 7   158                 Star Wars         True
# 12  246              Harry Potter         True
# 16  263  Pirates of the Caribbean         True
# 17  264             Indiana Jones         True
# 18  269                      Cars         True

# %%
parent_themes.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %%
df.head()
# Out:
#   set_num                        name  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space

# %%
merged = df.merge(parent_themes, left_on='parent_theme', right_on='name')
merged.drop(columns= 'name_y', inplace= True)
merged.head()
# Out:
#   set_num                      name_x  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme   id  is_licensed
# 0     Legoland  411        False
# 1         Town   50        False
# 2       Castle  186        False
# 3        Space  126        False
# 4        Space  126        False

# %%
# retorna apenas as licensed = true
licensed = merged[merged['is_licensed']]
licensed = licensed.dropna(subset=['set_num'])
licensed.head()

# filtra o df licensed por star wars
stars_wars_a = licensed[licensed['parent_theme'] == 'Star Wars']

stars_wars_a.head()
# Out:
#      set_num                         name_x  year  num_parts  \
# 44   10018-1                     Darth Maul  2001     1868.0
# 45   10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 54   10026-1        Naboo Starfighter - UCS  2002        NaN
# 57   10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 116  10123-1                     Cloud City  2003      707.0
#
#                   theme_name parent_theme   id  is_licensed
# 44                 Star Wars    Star Wars  158         True
# 45   Star Wars Episode 4/5/6    Star Wars  158         True
# 54       Star Wars Episode 1    Star Wars  158         True
# 57   Star Wars Episode 4/5/6    Star Wars  158         True
# 116  Star Wars Episode 4/5/6    Star Wars  158         True

# %% [markdown]
# ## Tarefa 01 - Qual a porcentagem de todos os conjuntos licenciados já lançados que tinham como tema Star Wars?

# %%
Porc_Conjuntos_licenciados_star_wars = int(stars_wars_a.shape[0]/licensed.shape[0]*100)
print(Porc_Conjuntos_licenciados_star_wars)
# Out:
# 51

# %% [markdown]
# ## Tarefa 02 - Em que ano Star Wars não foi o tema licenciado mais popular (em termos de número de conjuntos lançados naquele ano)?

# %%
licensed_sorted = licensed.sort_values('year')
licensed_sorted['count'] = 1
licensed_sorted.head()

summed_df = licensed_sorted.groupby(['year','parent_theme']).sum().reset_index()

max_df = summed_df.sort_values('count',ascending = False).drop_duplicates(['year'])

max_df.sort_values('year', inplace=True)
max_df
# Out:
#     year  parent_theme                                            set_num  \
# 0   1999     Star Wars  7140-17141-17150-17151-17110-17101-17121-17130...
# 2   2000     Star Wars  8000-18002-17115-13342-13341-17144-17124-17134...
# 4   2001     Star Wars  8008-17146-17126-17127-17106-165034-165030-165...
# 6   2002     Star Wars  4195641-165153-165106-17103-17203-17204-17133-...
# 9   2003     Star Wars  4501-14482-14481-14480-14500-1K4479-1K4487-144...
# 12  2004     Star Wars  10131-110134-16964-26963-17262-16964-16963-269...
# 16  2005     Star Wars  7250-17258-17257-17256-17252-17255-16966-16965...
# 20  2006     Star Wars  6205-16210-16206-16207-110175-17261-26212-1621...
# 24  2007     Star Wars  7660-17661-17657-110179-17665-17666-17662-1766...
# 28  2008     Star Wars  10188-110186-17680-17679-17678-17676-17681-176...
# 32  2009     Star Wars  20009-120007-120010-17749-17748-1comcon007-1co...
# 36  2010     Star Wars  20016-12853835-18128-130050-18129-18086-18085-...
# 42  2011     Star Wars  10221-15000067-120021-120019-17957-166396-1663...
# 47  2012     Star Wars  9494-19675-19676-19677-19678-19679-110225-1102...
# 52  2013     Star Wars  10240-1comcon032-175007-166449-15001709-150016...
# 59  2014     Star Wars  75024-166515-166514-166512-1TRUXWINGTIE-150021...
# 67  2015     Star Wars  5002939-15002938-175099-175096-1celeb2015-1751...
# 76  2016     Star Wars  SW911617-1SW911608-111912-175118-175119-175120...
# 82  2017  Super Heroes  76082-176072-171017-1830612-130607-130546-1305...
#
#                                                name_x  num_parts  \
# 0   X-wing FighterNaboo FighterTIE Fighter & Y-win...     1384.0
# 2   Pit Droid™ / Star Wars Pit DroidDestroyer Droi...     2580.0
# 4   Stormtrooper™TIE FighterBattle Droid CarrierIm...     2949.0
# 6   Star Wars Co-Pack of 7142 and 7152Jango Fett's...     4735.0
# 9   Mos Eisley Cantina, Blue boxAT-TEHailfire Droi...     6660.0
# 12  TIE Fighter CollectionY-wing Attack Starfighte...     1659.0
# 16  Clone Scout WalkerWookiee AttackUltimate Light...     4730.0
# 20  V-wing FighterJabba's Sail BargeTIE Intercepto...     2769.0
# 24  Naboo N-1 Starfighter and Vulture DroidJedi St...    11361.0
# 28  Death StarGeneral GrievousThe Twilight - Limit...     6865.0
# 32  AT-TE Walker - MiniRepublic Attack Cruiser - M...     3953.0
# 36  Imperial Shuttle - MiniWhite Boba Fett FigureC...     6003.0
# 42  Super Star DestroyerStar Wars Sith KitBounty H...     3451.0
# 47  Anakin's Jedi InterceptorSebulba's Podracer & ...     6769.0
# 52  Red Five X-Wing StarfighterJEK-14 Mini Stealth...     6159.0
# 59  HH-87 StarhopperStar Wars Microfighters Super ...     8293.0
# 67  The PhantomStormtrooper SergeantRey's Speeder™...    11410.0
# 76  Palpatine's ShuttleLandspeederLEGO Star Wars: ...     6934.0
# 82  ATM Heist BattleMighty Micros: Iron Man vs. Th...    13123.0
#
#                                            theme_name     id  is_licensed  \
# 0   Star Wars Episode 4/5/6Star Wars Episode 1Star...   2054           13
# 2   Star WarsStar WarsStar Wars Episode 1Star Wars...   4108           26
# 4   Star WarsStar Wars Episode 4/5/6Star Wars Epis...   2212           14
# 6   Star Wars Episode 4/5/6Star Wars Episode 2Star...   4424           28
# 9   Star Wars Episode 4/5/6Star Wars Episode 2Star...   5056           32
# 12  Star Wars Episode 4/5/6Star Wars Episode 4/5/6...   3160           20
# 16  Star Wars Episode 3Star Wars Episode 3Star War...   4424           28
# 20  Star Wars Episode 3Star Wars Episode 4/5/6Star...   1738           11
# 24  Star Wars Episode 1Star Wars Episode 3Star War...   2528           16
# 28  Star Wars Episode 4/5/6Star Wars Episode 3Star...   3634           23
# 32  Star Wars Episode 2Star Wars Episode 3Star War...   6162           39
# 36  Star Wars Episode 4/5/6Star WarsStar Wars Clon...   4740           30
# 42  Star Wars Episode 4/5/6Star WarsStar Wars Clon...   5056           32
# 47  Star Wars Episode 3Star Wars Episode 1Star War...   6794           43
# 52  Star Wars Episode 4/5/6Star WarsStar WarsStar ...   5530           35
# 59  Star Wars Clone WarsMiniMiniStar Wars RebelsSt...   7110           45
# 67  Star Wars RebelsStar WarsStar WarsStar Wars Ep...   9164           58
# 76  Star WarsStar Wars Episode 4/5/6Star WarsStar ...   9638           61
# 82  MarvelSuper HeroesBatmanBatmanBatmanSuper Hero...  34704           72
#
#     count
# 0      13
# 2      26
# 4      14
# 6      28
# 9      32
# 12     20
# 16     28
# 20     11
# 24     16
# 28     23
# 32     39
# 36     30
# 42     32
# 47     43
# 52     35
# 59     45
# 67     58
# 76     61
# 82     72

# %%
indice_maximo = max_df['count'].idxmax()

ano_maximo = max_df.loc[indice_maximo, 'year']
print(ano_maximo)
# Out:
# 2017

# %%
#join entre a tabela df e temas_licenciado para retornar a coluna is_license na tabela df
licensed_lego_sets = df.merge(temas_licenciado, left_on='parent_theme', right_on='name')
licensed_lego_sets.head(10)
# Out:
#    set_num                           name_x  year  num_parts  \
# 0  10018-1                       Darth Maul  2001     1868.0
# 1  10019-1      Rebel Blockade Runner - UCS  2001        NaN
# 2  10026-1          Naboo Starfighter - UCS  2002        NaN
# 3  10030-1    Imperial Star Destroyer - UCS  2002     3115.0
# 4  10075-1           Spider-Man Action Pack  2002       25.0
# 5  10123-1                       Cloud City  2003      707.0
# 6  10129-1          Rebel Snowspeeder - UCS  2003     1456.0
# 7  10131-1           TIE Fighter Collection  2004        NaN
# 8  10132-1       Motorized Hogwarts Express  2004        NaN
# 9  10134-1  Y-wing Attack Starfighter - UCS  2004        NaN
#
#                 theme_name  parent_theme   id        name_y  is_licensed
# 0                Star Wars     Star Wars  158     Star Wars         True
# 1  Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
# 2      Star Wars Episode 1     Star Wars  158     Star Wars         True
# 3  Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
# 4               Spider-Man  Super Heroes  482  Super Heroes         True
# 5  Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
# 6  Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
# 7  Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
# 8             Harry Potter  Harry Potter  246  Harry Potter         True
# 9  Star Wars Episode 4/5/6     Star Wars  158     Star Wars         True
